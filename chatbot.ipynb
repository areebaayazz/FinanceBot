# %% [markdown]
# ## Install Required Packages

# %%
# !pip install Flask werkzeug  gpt4all huggingface-hub pypdf2 streamlit python-dotenv faiss-cpu chromadb langchain SpeechRecognition pydub langchain-together
# Out:
# Requirement already satisfied: Flask in c:\users\mod\anaconda3\lib\site-packages (2.2.5)
# Requirement already satisfied: werkzeug in c:\users\mod\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: gpt4all in c:\users\mod\anaconda3\lib\site-packages (2.2.1.post1)
# Requirement already satisfied: huggingface-hub in c:\users\mod\anaconda3\lib\site-packages (0.21.4)
# Requirement already satisfied: pypdf2 in c:\users\mod\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: streamlit in c:\users\mod\anaconda3\lib\site-packages (1.30.0)
# Requirement already satisfied: python-dotenv in c:\users\mod\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: faiss-cpu in c:\users\mod\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: chromadb in c:\users\mod\anaconda3\lib\site-packages (0.4.24)
# Requirement already satisfied: langchain in c:\users\mod\anaconda3\lib\site-packages (0.1.11)
# Requirement already satisfied: SpeechRecognition in c:\users\mod\anaconda3\lib\site-packages (3.10.1)
# Requirement already satisfied: pydub in c:\users\mod\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\mod\anaconda3\lib\site-packages (from Flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\mod\anaconda3\lib\site-packages (from Flask) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\mod\anaconda3\lib\site-packages (from Flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mod\anaconda3\lib\site-packages (from werkzeug) (2.1.3)
# Requirement already satisfied: requests in c:\users\mod\anaconda3\lib\site-packages (from gpt4all) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\mod\anaconda3\lib\site-packages (from gpt4all) (4.65.0)
# Requirement already satisfied: filelock in c:\users\mod\anaconda3\lib\site-packages (from huggingface-hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mod\anaconda3\lib\site-packages (from huggingface-hub) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mod\anaconda3\lib\site-packages (from huggingface-hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mod\anaconda3\lib\site-packages (from huggingface-hub) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mod\anaconda3\lib\site-packages (from huggingface-hub) (23.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (6.11.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\mod\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: build>=1.0.3 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.1.1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\mod\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.27.1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (3.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.17.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (6.1.3)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (1.62.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\mod\anaconda3\lib\site-packages (from chromadb) (3.9.15)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.25 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (0.0.27)
# Requirement already satisfied: langchain-core<0.2,>=0.1.29 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (0.1.30)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\mod\anaconda3\lib\site-packages (from langchain) (0.1.22)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mod\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mod\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mod\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mod\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mod\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mod\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\mod\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: pyproject_hooks in c:\users\mod\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: colorama in c:\users\mod\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mod\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mod\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in c:\users\mod\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.36.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mod\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\mod\anaconda3\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mod\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.28.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\mod\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: anyio<5,>=3 in c:\users\mod\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1.29->langchain) (4.2.0)
# Requirement already satisfied: coloredlogs in c:\users\mod\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\mod\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.6)
# Requirement already satisfied: sympy in c:\users\mod\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\mod\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.7.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mod\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mod\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: monotonic>=1.5 in c:\users\mod\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\mod\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mod\anaconda3\lib\site-packages (from requests->gpt4all) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mod\anaconda3\lib\site-packages (from requests->gpt4all) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\mod\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mod\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mod\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: h11>=0.8 in c:\users\mod\anaconda3\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\mod\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\mod\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\mod\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\mod\anaconda3\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mod\anaconda3\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.29->langchain) (1.3.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\mod\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mod\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mod\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mod\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mod\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mod\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mod\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mod\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\mod\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mod\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\mod\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mod\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %% [markdown]
# ## Imports

# %%
from langchain.llms import Together
from langchain.memory import ConversationBufferMemory
from langchain.chains import LLMChain
from langchain_core.prompts import PromptTemplate
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import GPT4AllEmbeddings
from langchain_together import Together
from langchain.callbacks.base import BaseCallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
import os
import chromadb

# %% [markdown]
# ## PDF Loader and Vector Database Creation

# %%
def load_chunk_persist_pdf() -> Chroma:
    pdf_folder_path = "./chat_pdf_data"
    documents = []
#     text = 'Who is Laurens van der Maaten?'
#     ST_embeddings = Embed4All('nomic-embed-text-v1.f16.gguf')
    ST_embeddings = gpt4all_embd = GPT4AllEmbeddings()
    

#     output = embedder.embed(text, prefix='search_document')
#     ST_embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

    for file in os.listdir(pdf_folder_path):
        if file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder_path, file)
            loader = PyPDFLoader(pdf_path)
            documents.extend(loader.load())
    text_splitter = CharacterTextSplitter(chunk_size=1024, chunk_overlap=64)
    chunked_documents = text_splitter.split_documents(documents)
    client = chromadb.Client()
    if client.list_collections():
        consent_collection = client.create_collection("collection")
    else:
        print("Collection already exists")
    vectordb = Chroma.from_documents(
        documents=chunked_documents,
        embedding=ST_embeddings,
        persist_directory="./chroma_store"
    )
    vectordb.persist()
    return vectordb

# %% [markdown]
# ## Agent Creation for Response Generation

# %%
def create_agent(context):

    # template = """
    # You are an expert accounting and a financial expert with expertise legislative knowledge of finance.
    # Explain the concept of {concept} in a couple of lines
    # """
    
    
    template = """
    As an expert with in-depth knowledge derived from key documents relevant to financial regulation and reporting in the UK, your role involves providing detailed and precise answers based on these texts. The documents you rely on include but are not limited to "Academies Accounts Direction 2022 to 2023," "Academies Model Accounts 2022 to 2023," "ATH 2023 Final," "Charities SORP FRS 102 (2019A)," "Companies Act 2006," "EFA Academies SORP Guide," "Framework and Guide for External Auditors 2022 to 2023," "FRS 100 Application of Financial Reporting Requirements (November 2022)," "FRS 103 Insurance Contracts," and "Redacted FRS 102 and FRS 105 (January 2022)."

Your answers must reflect a formal, professional tone, with each articulated in complete sentences ending with a full stop. Avoid harmful, disrespectful, or sensitive remarks.

When addressing inquiries:

1. Acknowledge the question or topic from the inquirer with a clear, initial sentence that concludes with a full stop. Clarify whether the query relates to regulatory practices, financial reporting standards, or other areas covered by the documents at your disposal.

2. Draw directly from the information within the specified documents to provide a detailed, informative response. If a question involves regulatory bodies such as the Financial Services Authority (FSA) and does not directly relate to the content of the listed documents, clearly state that the detailed answer is based on available information within the context of these documents and that specific regulatory inquiries may require consultation of direct regulatory advisories or legal guidelines.

3. Conclude your response with a summary of the key points or a concise recapitulation for clarity. Ensure the final sentence also ends with a full stop.

Context and previous interactions are as follows:
 
    Current Conversation
    Context: {context}
        
    {history}
    
    Human: {question}
    
    AI Assistant:
    
    """
    memory = ConversationBufferMemory(memory_key="history" ,input_key="question" )



    callback_manager = BaseCallbackManager([StreamingStdOutCallbackHandler()])
    # llm = GPT4All(model=gpt4all_path, max_tokens=1000,  callback_manager=callback_manager, verbose=True,repeat_last_n=0)

    llm = Together(
        model="mistralai/Mixtral-8x7B-Instruct-v0.1",
        temperature=0.5,
        callback_manager=callback_manager,
        max_tokens=600,
        top_k=1,
        top_p=1,        
        together_api_key="5ffb2e029349afeb3e62f25e83ea59499faa529df818c06782b7923e3a5e0aa1"
    )

    # callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])


    # If you want to use a custom model add the backend parameter
    # Check https://docs.gpt4all.io/gpt4all_python.html for supported backends
#     llm = GPT4All("./models/all-MiniLM-L6-v2-f16.gguf")

#     llm = LlamaCpp(
#         model_path="./models/mistral-7b-instruct-v0.1.Q4_0.gguf",
# #         n_ctx=5000,
# #         n_gpu_layers=1,
# #         n_batch=512,
#         f16_kv=True,  # MUST set to True, otherwise you will run into problem after a couple of calls
#         callback_manager=callback_manager,
#         verbose=True,

#     )

#     llm = GPT4All(model="./models/mistral-7b-instruct-v0.1.Q4_0.gguf",n_ctx=1000, callback_manager=callback_manager, verbose=False,repeat_last_n=0)
#     prompt = PromptTemplate(template=template, input_variables=["question","context","chat_history"]).partial(context=context)
    prompt = PromptTemplate(input_variables=["history", "question","context"], template=template).partial(context=context)
    llm_chain = LLMChain(prompt=prompt, llm=llm,verbose = False, memory=memory)

    return llm_chain

# %% [markdown]
# ## Response Generation

# %%
def get_llm_response(query,context,vectordb):
    matching_docs = vectordb.similarity_search(query)
    context = ""

    for doc in matching_docs:
        context = context + doc.page_content + " \n\n "
    
    chain = create_agent(context)

    answer = chain.run(input_documents=matching_docs, question=query)
    return answer

# %% [markdown]
# ## Initialize vector database (run only once as needed)

# %%
vectordb = load_chunk_persist_pdf()
# Out:
# Collection already exists

# %% [markdown]
# ## Flask Backend

# %%
from flask import Flask, render_template, request, jsonify
from werkzeug.serving import run_simple

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('indexx.html')

@app.route('/ask', methods=['POST'])
def ask():
    question = request.form['question']
    context = request.form['context']  # You might want to handle context from the front-end
    # Call your chatbot function here
    response = get_llm_response(question, context, vectordb)
    return jsonify({'response': response})

if __name__ == '__main__':
    run_simple('localhost', 5000, app)
# Out:
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [19/May/2024 18:06:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:06:03] "GET /static/chatbot_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:06:03] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [19/May/2024 18:06:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:06:09] "GET /static/chatbot_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:06:10] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [19/May/2024 18:06:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:06:37] "GET /static/chatbot_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:06:38] "GET /favicon.ico HTTP/1.1" 404 -
# D:\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# 127.0.0.1 - - [19/May/2024 18:06:46] "POST /ask HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:07:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:10:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:10:21] "GET /static/chatbot_logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2024 18:10:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:10:26] "GET /static/chatbot_logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2024 18:10:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:10:34] "GET /static/chatbot_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2024 18:10:56] "GET / HTTP/1.1" 200 -
